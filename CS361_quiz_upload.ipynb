# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Preparation

# %%
quiz_percentage1 = pd.read_csv("CS_361_Fa2024_Q6_instances.csv")
max_point = quiz_percentage1.loc[1, "Max points"]
print(f"Max Point: {max_point}")
quiz_percentage1 = quiz_percentage1.rename(columns={'Score (%)': 'First Score (%)'})
quiz_percentage1 = quiz_percentage1.rename(columns={'Username': 'SID'})

quiz_percentage1 = quiz_percentage1[["SID", "Started", "First Score (%)"]]
print(quiz_percentage1.shape)
quiz_percentage1.head()
# Out:
# Max Point: 14
# (243, 3)
#         SID                 Started  First Score (%)
# 0   aadand2  2024-11-03T22:13:30-06        85.714286
# 1    aalex9  2024-11-03T23:34:33-06        85.714286
# 2   aaronw8  2024-11-01T14:44:00-05        85.714286
# 3  aarora14  2024-11-02T13:58:23-05        71.428571
# 4  aashayd2  2024-11-04T17:35:17-06        95.000000

# %%
for index, row in quiz_percentage1.iterrows():
  # netid = row["UID"].split("@")[0]
  # quiz_percentage1.loc[index, "SID"] = netid
  quiz_percentage1.loc[index, "First Score (%)"] = min(100, row["First Score (%)"])  # cap at 100

quiz_percentage1.head()
# Out:
#         SID                 Started  First Score (%)
# 0   aadand2  2024-11-03T22:13:30-06        85.714286
# 1    aalex9  2024-11-03T23:34:33-06        85.714286
# 2   aaronw8  2024-11-01T14:44:00-05        85.714286
# 3  aarora14  2024-11-02T13:58:23-05        71.428571
# 4  aashayd2  2024-11-04T17:35:17-06        95.000000

# %%
quiz_percentage2 = pd.read_csv("CS_361_Fa2024_Q6_instances_2.csv")
quiz_percentage2 = quiz_percentage2.rename(columns={'Score (%)': 'Second Score (%)'})
quiz_percentage2 = quiz_percentage2.rename(columns={'Username': 'SID'})
quiz_percentage2 = quiz_percentage2[["SID", "Second Score (%)"]]
print(quiz_percentage2.shape)
quiz_percentage2.head()
# Out:
# (161, 2)
#         SID  Second Score (%)
# 0   aadand2             100.0
# 1   aaronw8             105.0
# 2  aarora14             105.0
# 3  aashayd2              95.0
# 4  adarshk5             105.0

# %%
for index, row in quiz_percentage2.iterrows():
  # netid = row["UID"].split("@")[0]
  # quiz_percentage2.loc[index, "SID"] = netid
  quiz_percentage2.loc[index, "Second Score (%)"] = min(100, row["Second Score (%)"])  # cap at 100

quiz_percentage2.head()
# Out:
#         SID  Second Score (%)
# 0   aadand2             100.0
# 1   aaronw8             100.0
# 2  aarora14             100.0
# 3  aashayd2              95.0
# 4  adarshk5             100.0

# %% [markdown]
# **Merge Two Tables**

# %%
for index, row in quiz_percentage1.iterrows():
  SID = row["SID"]
  if SID not in quiz_percentage2['SID'].values:
    quiz_percentage2.loc[len(quiz_percentage2)] = [SID, np.nan]

print(quiz_percentage2.shape)
quiz_percentage2
# Out:
# (243, 2)
#           SID  Second Score (%)
# 0     aadand2             100.0
# 1     aaronw8             100.0
# 2    aarora14             100.0
# 3    aashayd2              95.0
# 4    adarshk5             100.0
# ..        ...               ...
# 238  yutongc3               NaN
# 239   zdeng14               NaN
# 240    zedds2               NaN
# 241  zjuszko2               NaN
# 242    zmoha7               NaN
#
# [243 rows x 2 columns]

# %%
quiz_average = pd.merge(quiz_percentage1, quiz_percentage2, on="SID")
quiz_average
# Out:
#           SID                 Started  First Score (%)  Second Score (%)
# 0     aadand2  2024-11-03T22:13:30-06        85.714286             100.0
# 1      aalex9  2024-11-03T23:34:33-06        85.714286               NaN
# 2     aaronw8  2024-11-01T14:44:00-05        85.714286             100.0
# 3    aarora14  2024-11-02T13:58:23-05        71.428571             100.0
# 4    aashayd2  2024-11-04T17:35:17-06        95.000000              95.0
# ..        ...                     ...              ...               ...
# 238   zehuaj2  2024-11-05T16:03:07-06        57.142857              90.0
# 239   zijiez4  2024-11-02T17:42:38-05        85.714286             100.0
# 240  zjuszko2  2024-11-08T15:58:12-06        71.428571               NaN
# 241   zkhan91  2024-11-01T21:24:19-05        71.428571             100.0
# 242    zmoha7  2024-11-01T10:48:41-05       100.000000               NaN
#
# [243 rows x 4 columns]

# %% [markdown]
# # Calculations

# %% [markdown]
# **Average two attempts properly**
#
#
# *   *Take first score as Average if no second attemp*

# %%
quiz_average['Average'] = quiz_average.apply(
    lambda row: row['First Score (%)'] if pd.isna(row['Second Score (%)'])
    else (row['First Score (%)'] + row['Second Score (%)']) / 2,
    axis=1
)
quiz_average
# Out:
#           SID                 Started  First Score (%)  Second Score (%)  \
# 0     aadand2  2024-11-03T22:13:30-06        85.714286             100.0
# 1      aalex9  2024-11-03T23:34:33-06        85.714286               NaN
# 2     aaronw8  2024-11-01T14:44:00-05        85.714286             100.0
# 3    aarora14  2024-11-02T13:58:23-05        71.428571             100.0
# 4    aashayd2  2024-11-04T17:35:17-06        95.000000              95.0
# ..        ...                     ...              ...               ...
# 238   zehuaj2  2024-11-05T16:03:07-06        57.142857              90.0
# 239   zijiez4  2024-11-02T17:42:38-05        85.714286             100.0
# 240  zjuszko2  2024-11-08T15:58:12-06        71.428571               NaN
# 241   zkhan91  2024-11-01T21:24:19-05        71.428571             100.0
# 242    zmoha7  2024-11-01T10:48:41-05       100.000000               NaN
#
#         Average
# 0     92.857143
# 1     85.714286
# 2     92.857143
# 3     85.714286
# 4     95.000000
# ..          ...
# 238   73.571429
# 239   92.857143
# 240   71.428571
# 241   85.714286
# 242  100.000000
#
# [243 rows x 5 columns]

# %%
quiz_average.to_csv("Quiz_6_Average.csv")

# %% [markdown]
# **Bonus**

# %%
import pytz
from datetime import datetime

# Define the due date with timezone
due_date_str = '2024-11-02T23:59'
due_date = pytz.timezone('America/Chicago').localize(datetime.strptime(due_date_str, '%Y-%m-%dT%H:%M'))
print(f"Due date: {due_date}")

# Comparison
for index, row in quiz_average.iterrows():
  start_date = pd.to_datetime(row["Started"])
  # print(f"Start Date: {start_date}")
  quiz_average.loc[index, "Is_On_Time"] = start_date < due_date
  quiz_average.loc[index, "Bonus Added"] = row["Average"] * (1.05) if row["Is_On_Time"] == True else row["Average"]
  quiz_average.loc[index, "Raw Points"] = row["Bonus Added"] * max_point / 100


quiz_average
# Out:
# Due date: 2024-11-02 23:59:00-05:00
#           SID                 Started  First Score (%)  Second Score (%)  \
# 0     aadand2  2024-11-03T22:13:30-06        85.714286             100.0
# 1      aalex9  2024-11-03T23:34:33-06        85.714286               NaN
# 2     aaronw8  2024-11-01T14:44:00-05        85.714286             100.0
# 3    aarora14  2024-11-02T13:58:23-05        71.428571             100.0
# 4    aashayd2  2024-11-04T17:35:17-06        95.000000              95.0
# ..        ...                     ...              ...               ...
# 238   zehuaj2  2024-11-05T16:03:07-06        57.142857              90.0
# 239   zijiez4  2024-11-02T17:42:38-05        85.714286             100.0
# 240  zjuszko2  2024-11-08T15:58:12-06        71.428571               NaN
# 241   zkhan91  2024-11-01T21:24:19-05        71.428571             100.0
# 242    zmoha7  2024-11-01T10:48:41-05       100.000000               NaN
#
#         Average Is_On_Time  Bonus Added  Raw Points
# 0     92.857143      False    92.857143       13.00
# 1     85.714286      False    85.714286       12.00
# 2     92.857143       True    97.500000       13.65
# 3     85.714286       True    90.000000       12.60
# 4     95.000000      False    95.000000       13.30
# ..          ...        ...          ...         ...
# 238   73.571429      False    73.571429       10.30
# 239   92.857143       True    97.500000       13.65
# 240   71.428571      False    71.428571       10.00
# 241   85.714286       True    90.000000       12.60
# 242  100.000000       True   105.000000       14.70
#
# [243 rows x 8 columns]

# %%
quiz_average.to_csv("Quiz_6_Grade.csv")
